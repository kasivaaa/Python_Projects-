# %%
import requests

# %% [markdown]
# ### Define API endpoint(URL)

# %%
url = "https:// jsonplaceholder.typicode.com/posts"

# %% [markdown]
# ### Send a GET request

# %%
url = "https://jsonplaceholder.typicode.com/posts"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Convert response to JSON

# %%
posts = response.json()
posts
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %% [markdown]
# ### Access and import the data

# %%
for post in posts[:5]:
    print(f"Title:{post['title']}")
    print(f"Body:{post['body']}")
    print("-" * 50)
# Out:
# Title:sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# Body:quia et suscipit
# suscipit recusandae consequuntur expedita et cum
# reprehenderit molestiae ut ut quas totam
# nostrum rerum est autem sunt rem eveniet architecto
# --------------------------------------------------
# Title:qui est esse
# Body:est rerum tempore vitae
# sequi sint nihil reprehenderit dolor beatae ea dolores neque
# fugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis
# qui aperiam non debitis possimus qui neque nisi nulla
# --------------------------------------------------
# Title:ea molestias quasi exercitationem repellat qui ipsa sit aut
# Body:et iusto sed quo iure
# voluptatem occaecati omnis eligendi aut ad
# voluptatem doloribus vel accusantium quis pariatur
# molestiae porro eius odio et labore et velit aut
# --------------------------------------------------
# Title:eum et est occaecati
# Body:ullam et saepe reiciendis voluptatem adipisci
# ...

# %% [markdown]
# ### Store the data in a CSV file

# %%
import csv

# %%
#store data
with open('posts.csv', 'w') as file:
    writer = csv.writer(file)
    writer.writerow(["Title", "Body"])
    

    for post in posts:
        writer.writerow([post['title'], post['body']])
        print("Data saved in posts.csv")
# Out:
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# Data saved in posts.csv
# ...

# %% [markdown]
# ### Using POST method

# %%
# Define the data for the new post
new_post = {
    "title": "New Post Title",
    "body": "This is the body of the new post.",
    "userId": 1
}

# %%
response = requests.post(url, json=new_post)
if response.status_code == 201:
    post = response.json()
    print(f"The post was created with ID: {post['id']}")
    print(post)
else:
    print("Failed to create post")
# Out:
# The post was created with ID: 101
# {'title': 'New Post Title', 'body': 'This is the body of the new post.', 'userId': 1, 'id': 101}

# %% [markdown]
# ### Import Libraries

# %%
import requests

# %% [markdown]
# ### Get user input

# %%
city = input("Enter a city")
city
# Out:
# 'Nairobi'

# %% [markdown]
# ### Prepare API endpoint

# %%
api_key = '592408cd4fd75a786cdcaa5ab2d4ed4f'
url_endpoint = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}'

# %% [markdown]
# ### Send Request to API

# %%
response = requests.get(url_endpoint)
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Convert response to JSON

# %%
data = response.json()
data
# Out:
# {'coord': {'lon': 36.8167, 'lat': -1.2833},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 290.68,
#   'feels_like': 290.16,
#   'temp_min': 290.68,
#   'temp_max': 290.68,
#   'pressure': 1019,
#   'humidity': 64,
#   'sea_level': 1019,
#   'grnd_level': 840},
#  'visibility': 10000,
#  'wind': {'speed': 1.74, 'deg': 78, 'gust': 3.2},
#  'clouds': {'all': 82},
#  'dt': 1782677382,
#  'sys': {'country': 'KE', 'sunrise': 1782617665, 'sunset': 1782661034},
#  'timezone': 10800,
#  'id': 184745,
#  'name': 'Nairobi',
#  'cod': 200}

# %% [markdown]
# ### Check if city exists

# %%
if data ["cod"] != 200:
    print(f"Error: {data['message']}")

# %% [markdown]
# ### Extract Weather Data

# %%
city_name = data['name']
temp =data['main']['temp']
weather = data['weather'][0]["description"]
humidity = data['main']['humidity']

# %% [markdown]
# ### Display weather data

# %%
print(f"\nWeather in {city_name}:")
print(f"\nTemperature: {temp}C")
print(f"\nCondition:{weather}")
print(f"\nHumidity: {humidity}")
# Out:
# Weather in Nairobi:
#
# Temperature: 290.68C
#
# Condition:broken clouds
#
# Humidity: 64

# %% [markdown]
# ### Get Countrys information using REST countries API

# %%
import requests

# %%
country = input("Enter a city: ")
country
# Out:
# 'kenya'

# %%
api_key = 'rc_live_a4c777680b3b446caa0828d786d1fa37'
url_endpoint = f"https://api.restcountries.com/countries/v5/names.common/Canada" \
  -H "Authorization: Bearer {your_api_key}"

# %%
response = requests.get(
  f'https://api.restcountries.com/countries/v5?q={country}',
  headers={'Authorization': 'Bearer rc_live_80c63e2ca8234770899c10b8f4165d24'}
)

# %%
# response = requests.get(url_endpoint)
response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# {'data': {'objects': [{'names': {'alternates': ['Jamhuri ya Kenya'],
#      'common': 'Kenya',
#      'native': {'eng': {'common': 'Kenya', 'official': 'Republic of Kenya'},
#       'swa': {'common': 'Kenya', 'official': 'Republic of Kenya'}},
#      'official': 'Republic of Kenya',
#      'translations': {'ara': {'common': 'كينيا', 'official': 'جمهورية كينيا'},
#       'bre': {'common': 'Kenya', 'official': 'Republik Kenya'},
#       'ces': {'common': 'Keňa', 'official': 'Keňská republika'},
#       'cym': {'common': 'Kenya', 'official': 'Republic of Kenya'},
#       'deu': {'common': 'Kenia', 'official': 'Republik Kenia'},
#       'est': {'common': 'Keenia', 'official': 'Keenia Vabariik'},
#       'fas': {'common': 'کنیا', 'official': 'جمهوری کنیا'},
#       'fin': {'common': 'Kenia', 'official': 'Kenian tasavalta'},
#       'fra': {'common': 'Kenya', 'official': 'République du Kenya'},
#       'hrv': {'common': 'Kenija', 'official': 'Republika Kenija'},
# ...

# %%
country = data["data"]["objects"][0]

print(f"Country: {country['names']['common']}")
print(f"Capital: {country['capitals'][0]['name']}")
print(f"Population: {country['population']:,}")
print(f"Region: {country['region']}")
print(f"Currency: {country['currencies'][0]['name']}")
print(f"Flag: {country['flag']['emoji']}")
# Out:
# Country: Kenya
# Capital: Nairobi
# Population: 53,330,978
# Region: Africa
# Currency: Kenyan shilling
# Flag: 🇰🇪
