# %%
fruits[apples, mangoes, grapes, bananas]

# %%
#lists

fruits = ["apples", "mangoes", "grapes", "bananas"]

# %%
fruits
# Out:
# ['apples', 'mangoes', 'grapes', 'bananas']

# %%
fruits.insert(0,"bananas")
fruits
# Out:
# ['bananas', 'apples', 'mangoes', 'grapes', 'bananas']

# %%
fruits.append("bananas")
fruits
# Out:
# ['bananas', 'apples', 'mangoes', 'grapes', 'bananas', 'bananas']

# %%
fruits.count("bananas")
# Out:
# 3

# %% [markdown]
# ## looping through a list

# %%
fruits
# Out:
# ['bananas', 'apples', 'mangoes', 'grapes', 'bananas', 'bananas']

# %%
#looping through a list
for fruit in fruits:
    print(fruit)
# Out:
# bananas
# apples
# mangoes
# grapes
# bananas
# bananas

# %%
sentence ="Data science is fun"
words = sentence.split()
words
# Out:
# ['Data', 'science', 'is', 'fun']

# %%
sentence = ' '.join(words)
sentence
# Out:
# 'Data science is fun'

# %%
numbers = [1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
# get the maximum value in the list
max(numbers)
min(numbers)
len(numbers)
# Out:
# 5

# %% [markdown]
# ## List comprehension

# %%
numbers = [1, 2, 3, 4, 5]

# get square of each number in the list
squares = []
for num in numbers:
    squares.append(num ** 2)
print(numbers)
print(squares)
# Out:
# [1, 2, 3, 4, 5]
# [1, 4, 9, 16, 25]

# %%
numbers = [1, 2, 3, 4, 5]

squares =[num ** 2 for num in numbers]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
   
numbers = [1, 4, 7, 10, 13, 16]
new_numbers = []
for num in numbers:
    if num % 2 == 0:
        new_num = i * 2
# Out:
# [3, 8, 21, 20, 39, 32]

# %% [markdown]
# ## Creating tuples

# %% [markdown]
# ### Difference between tuples and lists
# #### 1. Tuples cannot be changed
# #### 2. Tuples use parentheis while lists use square  brackets

# %%
# empty tuple 

empty = ()


#tuples
numbers = (1, 2, 3, 4, 5)

#tuple of strings
fruits = ("apples", "mangoes", "grapes", "bananas")

#tuple with mixed data types
mixed_tuple = (1, "apples", 3.14, True)

print(numbers)
print(empty)
print(fruits)
print(mixed_tuple)
# Out:
# (1, 2, 3, 4, 5)
# ()
# ('apples', 'mangoes', 'grapes', 'bananas')
# (1, 'apples', 3.14, True)

# %%
## Accesing Elements in a Tuple
fruits
# Out:
# ('apples', 'mangoes', 'grapes', 'bananas')

# %%
## accessing elements in a tuple using indexing
fruits[2:3]
# Out:
# ('grapes',)

# %%
fruits [:: -1]
# Out:
# ('bananas', 'grapes', 'mangoes', 'apples')

# %% [markdown]
# #### Question 1 2.1

# %%
sentence = input("Enter a sentence: ")
words = sentence.split()    
num_words = len(words)

print("Number of words in the sentence:", num_words)
# Out:
# Number of words in the sentence: 3

# %% [markdown]
# #### Question 1 2.2

# %%
company = {
    "HR": {
        "employee1": {"name": "Alice", "role": "HR Manager"},
        "employee2": {"name": "Bob", "role": "Recruiter"}
    },
    "IT": {
        "employee1": {"name": "Charlie", "role": "IT Support"},
        "employee2": {"name": "David", "role": "Software Engineer"}
    },
    "Finance": {
        "employee1": {"name": "Eve", "role": "Financial Analyst"},
        "employee2": {"name": "Frank", "role": "Accountant"}
    }
}

# %%
numbers = [5, 2, 9, 1, 5, 6]
sorted_numbers = sorted(numbers)
print(sorted_numbers)
# Out:
# [1, 2, 5, 5, 6, 9]

# %% [markdown]
# #### Question 2 2.2

# %%
l1 = [43, 89, 67, 56, 12]
largest_number = max(l1)
print("The largest number in the list is:", largest_number)
# Out:
# The largest number in the list is: 89

# %% [markdown]
# ## Question 1 2.3

# %%
my_dict = {"a": 1, "b": 2, "c": 3}
total_sum = sum(my_dict.values())
print("The sum of all items in the dictionary is:", total_sum)
# Out:
# The sum of all items in the dictionary is: 6

# %% [markdown]
# ## Question 2 2.3

# %%
##Create a dictionary to store product information (name, price, quantity). Allow users to add, update, and remove items from the inventory.
inventory = {}

def add_product(name, price, quantity):
    inventory[name] = {"price": price, "quantity": quantity}
    print(f"Product '{name}' added to inventory.")
def update_product(name, price=None, quantity=None):
    if name in inventory:
        if price is not None:
            inventory[name]["price"] = price
        if quantity is not None:
            inventory[name]["quantity"] = quantity
        print(f"Product '{name}' updated in inventory.")
    else:
        print(f"Product '{name}' not found in inventory.")

def remove_product(name):
    if name in inventory:
        del inventory[name]
        print(f"Product '{name}' removed from inventory.")
    else:
        print(f"Product '{name}' not found in inventory.")
