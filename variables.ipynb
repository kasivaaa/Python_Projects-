# %%
print('hello world')

# %%
print('hello world')
# Out:
# hello world

# %%
name = 'Nicole'
y = 5
x = 4.2
is_student = True
print(name)
print(x)
print(y)
print(is_student)
# Out:
# Nicole
# 4.2
# 5
# True

# %% [markdown]
# print (f'Name: {name}, y: {5}, x: {x}, is_student: {is_student})

# %%
print (f"Name: {name}, y: {5}, x: {x}, is_student: {is_student}")
# Out:
# Name: Nicole, y: 5, x: 4.2, is_student: True

# %% [markdown]
# ## Variable types

# %%
print(type(name))
print(type(y))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ## Type casting

# %%
x =int ("3")
type(x)
# Out:
# int

# %% [markdown]
# ## Legal Variable Names

# %%
myVar = "Nicole"
my_Var = "Mercy"
_my_Var = 5
myVar2 =67
MYVAY= 9890

# %% [markdown]
# ## Illegal Variable Names

# %%
# 76name = "Nicole"
name@ = "Nicole"
# Out:
#   Cell In[13], line 2
#     name@ = "Nicole"
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Operators in python

# %%
x = 10
y = 5

sum = x + y
difference = x-y 
quotient = x / y 
floor_division = x // y
exponential = x ** y

# %%
print(sum)
print(difference)
print(quotient)
print(floor_division)
print(exponential)
# Out:
# 15
# 5
# 2.0
# 2
# 100000

# %% [markdown]
# ## Comparison Operators

# %%
a = 5
b = 10

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ## Logical operators

# %%
# using logical operators 
x = 5 
print (x >3 and x<10)
# Out:
# True

# %%
print (x>3 or  x<4 )
print(not (x>3 and x<4))
# Out:
# True
# True

# %% [markdown]
# ## Assignment opertaors

# %%
x = 5 
x += 3 
print (x)
# Out:
# 8

# %%
x = 6
x = "Nicole"
print (x)
# Out:
# Nicole

# %% [markdown]
# ### Examples using assignament operators

# %%
x = 5
x += 3
x -= 2
x *=4
x /= 6
print(x)
# Out:
# 4.0

# %% [markdown]
# ## Order of operations

# %%
result = 2+ 3* 4 Bodmas 
print(result)
# Out:
# 14

# %% [markdown]
#     # Types of expression

# %%
results = 10 + 5 *2
results
# Out:
# 20

# %% [markdown]
#  ## String expressions: Combine or manipulate text

# %%
Greetings= "Hi, " + "my name " + "is" +  " Nicole"
Greetings
# Out:
# 'Hi, my name is Nicole'

# %% [markdown]
# ## Asking user for input

# %%
name = input("Enter your name: ")
print(f"ENTER YOUR NAME, {name}")
print(type(name))
# Out:
# Hello, Nicole

# %% [markdown]
# ## Converting input to other types

# %%
age_str = input("Enter your age: ")
age = int (age_str) 
type(age_str)

print(f" In the next 5 years, you will be {age  + 5}")
# Out:
#  In the next 5 years, you will be 37

# %% [markdown]
# ## Converting to float

# %%
price = float(input(" Enter the price: "))
print(f"The price with the tax is : { price *0.10 + price}")
# Out:
# The price with the tax is : 220.0

# %%
age =int(input("Enter your age: "))
years_left = 100 - age
print("Years left", years_left)
# Out:
# Years left 0

# %%
anything = input()
print ("You typed: , anything ")
# Out:
# You typed: , anything

# %% [markdown]
# ## Question 1

# %%
x=10
y=5

sum  = x+y
difference  = x-y 
quotient = x / y

print (sum)
print(difference)
print(quotient)
# Out:
# 15
# 5
# 2.0

# %% [markdown]
# ## Question 2

# %%
name = input("Enter your name: ")
print(f"ENTER YOUR NAME: {name} , Welcome {name}")
print(type(name))
# Out:
# ENTER YOUR NAME: Nicole , Welcome Nicole
# <class 'str'>

# %%
hours = int(input("Enter your hours :"))
rate = int(input("Enter your rate :"))

grossSalary = hours * rate 
print(  " GrossSalary:", grossSalary)
# Out:
#  GrossSalary: 42
