# %% [markdown]
# ## Dictionary
# ##### A dictionary in Python is an unordered, mutable, and indexed collection of key-value pairs.
# ##### Each item in a dictionary is stored as:
#
# ##### key: value
#
# ##### Keys must be unique and immutable (e.g., strings, numbers, tuples).
# ##### Values can be of any data type and can repeat.

# %% [markdown]
# #### Creating a dictionary

# %%
#empty dictionary
empty = {}
empty
# Out:
# {}

# %%
#dictionary with data
student = {
    "name": "John Doe",
    "age": 21,
    "grade": "A"
}
student
# Out:
# {'name': 'John Doe', 'age': 21, 'grade': 'A'}

# %%
students = {
    "names": ["Alice", "Bob", "Charlie"],
    "age": [20, 22, 23],
    "grades": ["A", "D", "B"]
}
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 23],
#  'grades': ['A', 'D', 'B']}

# %% [markdown]
# ### Accessing dicionary values

# %%
student
# Out:
# {'name': 'John Doe', 'age': 21, 'grade': 'A'}

# %%
#Accesing the name using an index
student["name"]
# Out:
# 'John Doe'

# %%
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 23],
#  'grades': ['A', 'D', 'B']}

# %%
student.get("names")
students.get("age")[1] # Accessing the second element in the age list
# Out:
# 22

# %% [markdown]
# ### Updating and adding items into a list

# %%
#update

students ["age"][2] = 27 
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 27],
#  'grades': ['A', 'D', 'B']}

# %%
students["email"] = ["alice@example.com"]
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 27],
#  'grades': ['A', 'D', 'B'],
#  'email': ['alice@example.com']}

# %% [markdown]
# ### Removing items

# %%
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 27],
#  'grades': ['A', 'D', 'B'],
#  'email': ['alice@example.com']}

# %%
students.pop("grades")
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 27],
#  'email': ['alice@example.com']}

# %% [markdown]
# ### Applying dictionaries

# %% [markdown]
# #### 1. Looping through keys/values:

# %%
for key in students.items():
    print(key)
# Out:
# ('names', ['Alice', 'Bob', 'Charlie'])
# ('age', [20, 22, 27])
# ('email', ['alice@example.com'])

# %%
students
# Out:
# {'names': ['Alice', 'Bob', 'Charlie'],
#  'age': [20, 22, 27],
#  'email': ['alice@example.com']}

# %%
"Faculty" in students
# Out:
# False

# %% [markdown]
# #### Nested Dictionaires

# %% [markdown]
# ##### You can create dictionaries inside dictionaries:

# %%
students = {
    "student1" : {
        "name": "Emily Clark",
        "age": 22,
        "grade": "B"
    },
    "student2" : {
        "name": "Michael Brown",
        "age": 24,
        "grade": "C"
    }
}
students
# Out:
# {'student1': {'name': 'Emily Clark', 'age': 22, 'grade': 'B'},
#  'student2': {'name': 'Michael Brown', 'age': 24, 'grade': 'C'}}

# %%
#dictionary
my_dict = {
    'apple': 10,
    'banana': 5,
    'orange': 8,
    'mango': 12
}

# Calculate the sum of all values
total = sum(my_dict.values())

# Display the result
print("The sum of all the values in the dictionary is:", total)
# Out:
# The sum of all the values in the dictionary is: 35

# %%
# Dictionary with tuples as values
my_dict = {
    'apple': (2, 4),
    'banana': (1, 3),
    'orange': (5,),
    'mango': (6, 2, 1)
}

total = sum([num for values in my_dict.values() for num in values])

print("The sum of all the values in the dictionary is:", total)
# Out:
# The sum of all the values in the dictionary is: 24
