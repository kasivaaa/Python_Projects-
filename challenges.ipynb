# %% [markdown]
# ## Question 1 (1.1)

# %%
num1 = int(input("Enter the first number:"))
num2 = int(input("Enter your second number:"))
operator=input("Enter an operator ( +, -, *, /):")

if operator == "+":
    result = num1 + num2
    print("Result =", result)
elif operator == "-":
    result = num1 - num2
    print("Result =", result)
elif operator == "*":
    result = num1 * num2
    print("Result =", result)
elif operator == "/":
    if num2 != 0:
        result = num1 / num2
        print("Result =", result)
    else:
        print("Error: Cannot divide by zero")
else:
    print("Invalid operator")

# %% [markdown]
# ## Question 2 (1.1)

# %%
import random
random_number = random.randint(1, 100)
print("Random number between 1 and 100:", random_number)
# Out:
# Random number between 1 and 100: 89

# %% [markdown]
# ## Question 3 (1.1)

# %%
import math
number = int(input("Enter a number to find its square root: "))
square_root = math.sqrt(number)
print("The square root of", number, "is", square_root)
# Out:
# The square root of 16 is 4.0

# %% [markdown]
# ## Question 1 (1.2)

# %%
import random 
random_number = random.randint(1, 100)
attempts = 5
print("Welcome to the Number Guessing Game!")
print("I have selected a random number between 1 and 100. Can you guess it ? You have", attempts, "attempts.")
for attempt in range(1, attempts + 1):
    guess = int(input("Enter your guess: "))
    
    if guess < random_number:
        print("Higher! Try again.")
    elif guess > random_number:
        print("Lower! Try again.")
    else:
        print("Congratulations! You've guessed the number in", attempt, "attempts!")
        break
if guess != random_number:
    print("Sorry, you've used all your attempts. The correct number was", random_number)
# Out:
# Welcome to the Number Guessing Game!
# I have selected a random number between 1 and 100. Can you guess it ? You have 5 attempts.
# Lower! Try again.
# Lower! Try again.
# Lower! Try again.
# Higher! Try again.
# Higher! Try again.
# Sorry, you've used all your attempts. The correct number was 30

# %% [markdown]
# ## Question 2(1.3)

# %%
import math

num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
operator = input("Enter the operator (+, -, *, /): ")

if operator == "+":
    result = num1 + num2
elif operator == "-":
    result = num1 - num2
elif operator == "*":
    result = num1 * num2
elif operator == "/":
    result = num1 / num2
else:
    print("Invalid operator!")
    exit()

print("The result is:", result)
# Out:
# The result is: 5.0

# %% [markdown]
# ## Question 3 (1.3)

# %%
number = int(input("Enter a number: "))
is_prime = True
i = 2
while i < number:
    if number % i == 0:
        is_prime = False
        break
    i += 1
    
if is_prime:
    print(number, "is a prime number.")
else:
    print(number, "is not a prime number.")
# Out:
# 5 is a prime number.

# %% [markdown]
# ## Question 4(1.3)

# %%
#Write a program that uses a for loop to print the multiplication table of a number entered by the user (up to a specified number of multiples)

import math
number = int(input("Enter a number : "))
multiples = int(input("Enter the number of multiples : "))

for i in range(1, multiples + 1):
    product = number * i
    print(number, "x", i, "=", product)
# Out:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27

# %% [markdown]
# ## Question 5 (1.3)

# %%
# Input from the user
n = int(input("Enter a number: "))

# Initialize sum
total = 0

# Calculate the sum using a for loop
for i in range(1, n + 1):
    total += i

# Display the result
print("The sum of numbers from 1 to", n, "is", total)
# Out:
# The sum of numbers from 1 to 10 is 55

# %% [markdown]
# ## Question 6 (1.3)

# %%
rows = int(input("Enter the number of rows: "))

for i in range(1, rows + 1):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# ## Question 1(1.4)

# %%
#Create a function that will determine whether a number is positive or negative  
def check_number(num):
    if num > 0:
        return "The number is positive."
    elif num < 0:
        return "The number is negative."
    else:
        return "The number is zero."

# %% [markdown]
# ## Question 2(1.4)

# %%
def area_of_square(side_length):
    return side_length * side_length


def area_of_rectangle(length, width):
    return length * width


def area_of_circle(radius):
    return math.pi * radius * radius

# Example usage
#print("Square area:", area_of_square(4))
print("Rectangle area:", area_of_rectangle(5, 3))
print("Circle area:", area_of_circle(2))
# Out:
# Rectangle area: 15
# Circle area: 12.566370614359172

# %% [markdown]
# ## Question 3

# %%
def calculate_grade(score):
    if score >= 90 and score <= 100:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    elif score >= 0:
        return "F"
    else:
        return "Invalid Score"

# Example usage
score = int(input("Enter your score: "))
print("Grade:", calculate_grade(score))
# Out:
# Grade: C

# %% [markdown]
# ## Question 1 (2.1)

# %%
sentence = input("Enter a sentence: ")
words = sentence.split()    
num_words = len(words)

print("Number of words in the sentence:", num_words)
# Out:
# Number of words in the sentence: 3

# %% [markdown]
# ## Question 2(2.1)

# %%
# Create a program that checks if two given strings are anagrams of each other.

def are_anagrams(str1, str2):
    # remove spaces and make lowercase for fair comparison
    str1 = str1.replace(" ", "").lower()
    str2 = str2.replace(" ", "").lower()

    # if lengths differ, they can't be anagrams
    if len(str1) != len(str2):
        return False

    # sort both strings and compare
    return sorted(str1) == sorted(str2)


# user input
word1 = input("Enter first string: ")
word2 = input("Enter second string: ")

# check result
if are_anagrams(word1, word2):
    print("The strings are anagrams.")
else:
    print("The strings are NOT anagrams.")
# Out:
# The strings are NOT anagrams.

# %% [markdown]
# ## Question 3 (2.1)

# %% [markdown]
# ## Question 4 2.1

# %%
# Open the existing file and read its contents
with open("anthem2.txt", "r") as source_file:
    content = source_file.read()

# Create a new file and write the copied contents
with open("copy.txt", "w") as new_file:
    new_file.write(content)

print("Contents copied successfully!")
# Out:
# Contents copied successfully!

# %% [markdown]
# ## Question 5 2.2

# %%
# Open the text file in read mode
file = open("example_1.txt", "r")

# Loop through each line in the file
for line in file:
    print(line)

# Close the file
file.close()
# Out:
# This is my first line.
#
# This is my second line.
